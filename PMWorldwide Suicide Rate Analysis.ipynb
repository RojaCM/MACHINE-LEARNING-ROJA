# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/MACHINE-LEARNING-ROJA/blob/main/PMWorldwide%20Suicide%20Rate%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a53cc669-033b-4cd6-b6da-4dc2e100ca47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a53cc669-033b-4cd6-b6da-4dc2e100ca47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving suicide.csv to suicide.csv

# %%
df=pd.read_csv('suicide.csv')

# %%
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1  \
# 0      Country       Year
# 1  Afghanistan       2019
# 2  Afghanistan       2018
# 3  Afghanistan       2017
# 4  Afghanistan       2016
#
#   Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease  \
# 0                                         Both sexes
# 1                                   35.3 [21.8-49.8]
# 2                                   35.4 [21.7-50.1]
# 3                                   35.5 [21.7-50.4]
# 4                                   35.6 [21.6-50.7]
#
#   Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.1  \
# 0                                               Male
# 1                                   34.4 [21.9-47.9]
# 2                                   34.7 [22.0-48.5]
# 3                                   35.0 [22.0-49.1]
# ...

# %%
df.shape
# Out:
# (3661, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1',
#        'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease',
#        'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.1',
#        'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.2',
#        'Crude suicide rates (per 100 000 population)',
#        'Crude suicide rates (per 100 000 population).1',
#        'Crude suicide rates (per 100 000 population).2'],
#       dtype='object')

# %%
#renaming the columns names
columns1=['country','year','probdyingboth','probdyingmale','probdyingfemale','suicideboth','suicidemale','suicidefemale']

# %%
values=df.iloc[1:,:].values

# %%
values
# Out:
# array([['Afghanistan', '2019', '35.3 [21.8-49.8]', ..., '4.1 [2.3-7.0]',
#         '4.6 [2.6-7.9]', '3.6 [2.0-5.9]'],
#        ['Afghanistan', '2018', '35.4 [21.7-50.1]', ..., '4.1 [2.3-6.8]',
#         '4.6 [2.6-7.8]', '3.5 [2.0-5.8]'],
#        ['Afghanistan', '2017', '35.5 [21.7-50.4]', ..., '4.1 [2.3-6.8]',
#         '4.6 [2.7-7.9]', '3.4 [2.0-5.7]'],
#        ...,
#        ['Zimbabwe', '2002', '22.7 [14.4-32.9]', ..., '13.4 [7.0-21.6]',
#         '15.5 [8.3-23.6]', '11.4 [5.7-19.7]'],
#        ['Zimbabwe', '2001', '21.7 [13.8-31.6]', ..., '12.8 [6.6-20.9]',
#         '14.4 [7.7-22.0]', '11.3 [5.4-19.8]'],
#        ['Zimbabwe', '2000', '21.4 [13.6-31.2]', ..., '13.3 [6.7-21.7]',
#         '14.1 [7.5-21.5]', '12.4 [5.9-21.9]']], dtype=object)

# %%
df1=pd.DataFrame(values,columns=columns)
df1
# Out:
#           country  year     probdyingboth     probdyingmale   probdyingfemale  \
# 0     Afghanistan  2019  35.3 [21.8-49.8]  34.4 [21.9-47.9]  36.2 [21.7-51.6]
# 1     Afghanistan  2018  35.4 [21.7-50.1]  34.7 [22.0-48.5]  36.0 [21.4-51.6]
# 2     Afghanistan  2017  35.5 [21.7-50.4]  35.0 [22.0-49.1]  35.9 [21.3-51.7]
# 3     Afghanistan  2016  35.6 [21.6-50.7]  35.1 [22.0-49.4]  36.0 [21.2-51.9]
# 4     Afghanistan  2015  35.6 [21.6-50.8]  35.4 [22.3-49.8]  35.7 [21.0-51.7]
# ...           ...   ...               ...               ...               ...
# 3655     Zimbabwe  2004  24.5 [15.7-35.3]  24.6 [16.7-34.7]  24.5 [15.0-35.8]
# 3656     Zimbabwe  2003  23.1 [14.7-33.4]  23.5 [15.9-33.3]  22.7 [13.7-33.5]
# 3657     Zimbabwe  2002  22.7 [14.4-32.9]  24.1 [16.3-33.9]  21.5 [13.0-32.0]
# 3658     Zimbabwe  2001  21.7 [13.8-31.6]  23.6 [16.0-33.2]  20.2 [12.1-30.4]
# 3659     Zimbabwe  2000  21.4 [13.6-31.2]  23.3 [15.9-32.8]  19.8 [11.7-29.9]
#
# ...

# %%
x=df1.iloc[:,2]
x
# Out:
# 0       35.3 [21.8-49.8]
# 1       35.4 [21.7-50.1]
# 2       35.5 [21.7-50.4]
# 3       35.6 [21.6-50.7]
# 4       35.6 [21.6-50.8]
#               ...
# 3655    24.5 [15.7-35.3]
# 3656    23.1 [14.7-33.4]
# 3657    22.7 [14.4-32.9]
# 3658    21.7 [13.8-31.6]
# 3659    21.4 [13.6-31.2]
# Name: probdyingboth, Length: 3660, dtype: object

# %%
a='roja.cm'
y=lambda a: a.split('.')
y(a)
# Out:
# ['roja', 'cm']

# %%
for col in columns[2:]:
  df1[col] =df1[col].map(lambda x: x.split('[')[0]).astype('float')

# %%
df1
# Out:
#           country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 0     Afghanistan  2019           35.3           34.4             36.2
# 1     Afghanistan  2018           35.4           34.7             36.0
# 2     Afghanistan  2017           35.5           35.0             35.9
# 3     Afghanistan  2016           35.6           35.1             36.0
# 4     Afghanistan  2015           35.6           35.4             35.7
# ...           ...   ...            ...            ...              ...
# 3655     Zimbabwe  2004           24.5           24.6             24.5
# 3656     Zimbabwe  2003           23.1           23.5             22.7
# 3657     Zimbabwe  2002           22.7           24.1             21.5
# 3658     Zimbabwe  2001           21.7           23.6             20.2
# 3659     Zimbabwe  2000           21.4           23.3             19.8
#
#       suicideboth  suicidemale  suicidefemale
# 0             4.1          4.6            3.6
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          3660 non-null   object
#  1   year             3660 non-null   object
#  2   probdyingboth    3660 non-null   float64
#  3   probdyingmale    3660 non-null   float64
#  4   probdyingfemale  3660 non-null   float64
#  5   suicideboth      3660 non-null   float64
#  6   suicidemale      3660 non-null   float64
#  7   suicidefemale    3660 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 228.9+ KB

# %%
df1.describe()
# Out:
#        probdyingboth  probdyingmale  probdyingfemale  suicideboth  \
# count    3660.000000    3660.000000      3660.000000  3660.000000
# mean       22.058415      25.639590        18.670464    10.629180
# std         8.170809       9.727201         7.530725     8.986046
# min         7.300000       9.600000         4.400000     0.000000
# 25%        16.100000      18.000000        13.100000     4.900000
# 50%        21.700000      24.500000        18.300000     8.100000
# 75%        26.600000      31.500000        23.300000    13.200000
# max        56.000000      64.100000        47.800000    92.600000
#
#        suicidemale  suicidefemale
# count  3660.000000    3660.000000
# mean     16.370546       5.055847
# std      14.950656       4.035543
# min       0.000000       0.000000
# 25%       7.000000       2.300000
# 50%      12.000000       4.000000
# 75%      20.200000       6.600000
# max     147.800000      39.500000

# %%
df1.isnull().sum()
# Out:
# country            0
# year               0
# probdyingboth      0
# probdyingmale      0
# probdyingfemale    0
# suicideboth        0
# suicidemale        0
# suicidefemale      0
# dtype: int64

# %%
overall_suicide=df1.groupby('country').sum()

# %%
overall_suicide
# Out:
#                                     probdyingboth  probdyingmale  \
# country
# Afghanistan                                 768.9          779.0
# Albania                                     330.9          405.6
# Algeria                                     310.1          332.3
# Angola                                      502.7          565.2
# Antigua and Barbuda                         362.9          399.4
# ...                                           ...            ...
# Venezuela (Bolivarian Republic of)          327.2          387.2
# Viet Nam                                    437.9          602.6
# Yemen                                       564.0          628.6
# Zambia                                      570.1          653.9
# Zimbabwe                                    569.6          590.5
#
#                                     probdyingfemale  suicideboth  suicidemale  \
# country
# Afghanistan                                   758.4         89.2         96.7
# ...

# %%
df1['ProbDying_male_minus_female'] =df1['probdyingmale'] - df1['probdyingfemale']
df1['Suicide_male_minus_female'] =df1['suicidemale'] -df1['suicidefemale']

# %%
df1
# Out:
#           country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 0     Afghanistan  2019           35.3           34.4             36.2
# 1     Afghanistan  2018           35.4           34.7             36.0
# 2     Afghanistan  2017           35.5           35.0             35.9
# 3     Afghanistan  2016           35.6           35.1             36.0
# 4     Afghanistan  2015           35.6           35.4             35.7
# ...           ...   ...            ...            ...              ...
# 3655     Zimbabwe  2004           24.5           24.6             24.5
# 3656     Zimbabwe  2003           23.1           23.5             22.7
# 3657     Zimbabwe  2002           22.7           24.1             21.5
# 3658     Zimbabwe  2001           21.7           23.6             20.2
# 3659     Zimbabwe  2000           21.4           23.3             19.8
#
#       suicideboth  suicidemale  suicidefemale  ProbDying_male_minus_female  \
# ...

# %%
df1.columns
# Out:
# Index(['country', 'year', 'probdyingboth', 'probdyingmale', 'probdyingfemale',
#        'suicideboth', 'suicidemale', 'suicidefemale',
#        'ProbDying_male_minus_female', 'Suicide_male_minus_female'],
#       dtype='object')

# %%
overall_suicides=df1.groupby('country').sum()

# %%
overall_suicides
# Out:
#                                     probdyingboth  probdyingmale  \
# country
# Afghanistan                                 768.9          779.0
# Albania                                     330.9          405.6
# Algeria                                     310.1          332.3
# Angola                                      502.7          565.2
# Antigua and Barbuda                         362.9          399.4
# ...                                           ...            ...
# Venezuela (Bolivarian Republic of)          327.2          387.2
# Viet Nam                                    437.9          602.6
# Yemen                                       564.0          628.6
# Zambia                                      570.1          653.9
# Zimbabwe                                    569.6          590.5
#
#                                     probdyingfemale  suicideboth  suicidemale  \
# country
# Afghanistan                                   758.4         89.2         96.7
# ...

# %%
overall_suicides.drop(['probdyingboth','probdyingmale','probdyingfemale','suicidemale','suicidefemale','ProbDying_male_minus_female','Suicide_male_minus_female'],axis=1,inplace=True)

# %%
overall_suicides['suicideboth'].sum()
# Out:
# 38902.8

# %%
overall_suicides.sort_values(by='suicideboth',ascending=False)
# Out:
#                        suicideboth
# country
# Lesotho                     1191.4
# Eswatini                     820.0
# Russian Federation           794.4
# Lithuania                    759.6
# Guyana                       691.5
# ...                            ...
# Grenada                       35.2
# Syrian Arab Republic          31.2
# Sao Tome and Principe         29.7
# Barbados                      22.6
# Antigua and Barbuda           13.1
#
# [183 rows x 1 columns]

# %%
overall_suicides.sort_values(by='suicideboth',ascending=False).tail()
# Out:
#                        suicideboth
# country
# Grenada                       35.2
# Syrian Arab Republic          31.2
# Sao Tome and Principe         29.7
# Barbados                      22.6
# Antigua and Barbuda           13.1

# %%
plt.subplots(figsize= (30, 20))
cr=overall_suicides['suicideboth'].sort_values(ascending=False)
ax=cr.plot.bar()
ax.set_xlabel('Country')
ax.set_ylabel('Suicide Both Male and Female')

ax.set_title('Country vs Suicide Both Male and Female')
plt.show()
print(cr)
# Out:
# country
# Lesotho                  1191.4
# Eswatini                  820.0
# Russian Federation        794.4
# Lithuania                 759.6
# Guyana                    691.5
#                           ...
# Grenada                    35.2
# Syrian Arab Republic       31.2
# Sao Tome and Principe      29.7
# Barbados                   22.6
# Antigua and Barbuda        13.1
# Name: suicideboth, Length: 183, dtype: float64

# %%
overall_suicides
# Out:
#                                     suicideboth
# country
# Afghanistan                                89.2
# Albania                                   117.5
# Algeria                                    66.6
# Angola                                    146.2
# Antigua and Barbuda                        13.1
# ...                                         ...
# Venezuela (Bolivarian Republic of)         70.4
# Viet Nam                                  138.8
# Yemen                                     116.3
# Zambia                                    204.0
# Zimbabwe                                  331.4
#
# [183 rows x 1 columns]

# %%
india_suicide=df1[df1['country']=='India']

# %%
india_suicide
# Out:
#      country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 1500   India  2019           21.9           24.6             19.0
# 1501   India  2018           22.0           24.7             19.1
# 1502   India  2017           22.2           25.0             19.3
# 1503   India  2016           22.6           25.4             19.7
# 1504   India  2015           22.6           25.4             19.8
# 1505   India  2014           22.0           24.9             19.0
# 1506   India  2013           22.7           26.0             19.3
# 1507   India  2012           23.7           27.5             19.7
# 1508   India  2011           23.9           28.0             19.5
# 1509   India  2010           23.7           28.0             19.1
# 1510   India  2009           23.2           27.5             18.7
# 1511   India  2008           23.3           27.4             19.1
# 1512   India  2007           23.1           26.9             19.3
# ...

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(15,6))
ax[0].plot([0,60],[0,60], linewidth=3, color='black')
sns.scatterplot(data=df1, x='probdyingmale', y='probdyingfemale', s=100, ax=ax[0])
ax[0].set_title('Dying rates by gender')
ax[1].plot([0,100],[0,100], linewidth=3, color='black')
sns.scatterplot(data=df1, x='suicidemale', y='suicidefemale', s=100, ax=ax[1])
ax[1].set_title('Suicide rates by gender')
# Out:
# Text(0.5, 1.0, 'Suicide rates by gender')

# %%
df1.columns
# Out:
# Index(['country', 'year', 'probdyingboth', 'probdyingmale', 'probdyingfemale',
#        'suicideboth', 'suicidemale', 'suicidefemale',
#        'ProbDying_male_minus_female', 'Suicide_male_minus_female'],
#       dtype='object')

# %%
sns.pairplot(df1)

# %%
top_deaths=df1.sort_values('probdyingboth',ascending=False).head()

# %%
top_deaths
# Out:
#        country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 1759  Kiribati  2000           56.0           64.1             47.8
# 1758  Kiribati  2001           55.7           63.9             47.4
# 1757  Kiribati  2002           55.4           63.6             47.1
# 1756  Kiribati  2003           54.9           63.0             46.8
# 1755  Kiribati  2004           54.6           62.6             46.7
#
#       suicideboth  suicidemale  suicidefemale  ProbDying_male_minus_female  \
# 1759         31.2         53.1            9.9                         16.3
# 1758         31.1         53.1            9.8                         16.5
# 1757         30.9         52.6            9.8                         16.5
# 1756         29.4         49.8            9.6                         16.2
# 1755         29.3         49.6            9.6                         15.9
#
#       Suicide_male_minus_female
# 1759                       43.2
# 1758                       43.3
# ...

# %%
top_suicide=df1.sort_values('suicideboth',ascending=False)

# %%
top_suicide.head(10)
# Out:
#       country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 1865  Lesotho  2014           48.1           54.3             42.9
# 1864  Lesotho  2015           47.9           54.0             42.8
# 1866  Lesotho  2013           47.3           53.4             42.1
# 1863  Lesotho  2016           46.3           52.7             41.1
# 1867  Lesotho  2012           45.7           51.9             40.4
# 1862  Lesotho  2017           44.2           51.0             38.5
# 1861  Lesotho  2018           43.4           50.4             37.8
# 1860  Lesotho  2019           42.7           49.4             37.5
# 1868  Lesotho  2011           43.9           50.6             38.1
# 1869  Lesotho  2010           43.2           50.4             36.8
#
#       suicideboth  suicidemale  suicidefemale  ProbDying_male_minus_female  \
# 1865         92.6        147.8           39.5                         11.4
# 1864         92.4        147.3           39.3                         11.2
# ...

# %%
df1[df1.country.isin(top_suicide['country'])].iloc[:10,:]
# Out:
#       country  year  probdyingboth  probdyingmale  probdyingfemale  \
# 1860  Lesotho  2019           42.7           49.4             37.5
# 1861  Lesotho  2018           43.4           50.4             37.8
# 1862  Lesotho  2017           44.2           51.0             38.5
# 1863  Lesotho  2016           46.3           52.7             41.1
# 1864  Lesotho  2015           47.9           54.0             42.8
# 1865  Lesotho  2014           48.1           54.3             42.9
# 1866  Lesotho  2013           47.3           53.4             42.1
# 1867  Lesotho  2012           45.7           51.9             40.4
# 1868  Lesotho  2011           43.9           50.6             38.1
# 1869  Lesotho  2010           43.2           50.4             36.8
#
#       suicideboth  suicidemale  suicidefemale  ProbDying_male_minus_female  \
# 1860         72.4        116.0           30.1                         11.9
# 1861         76.6        124.6           29.9                         12.6
# ...

# %%
data_top_10_death=top_suicide.head(10)
plt.figure(figsize=(15,6))
sns.lineplot(data=data_top_10_death, x='year', y='probdyingboth', hue='country')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
