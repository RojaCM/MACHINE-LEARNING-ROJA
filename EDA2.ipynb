# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/MACHINE-LEARNING-ROJA/blob/main/EDA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0f47b35e-3163-4dec-b48d-6af0b8aaf297" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f47b35e-3163-4dec-b48d-6af0b8aaf297">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic.csv

# %%
df=pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1=df.drop('PassengerId',axis=1)

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df1.shape
# Out:
# (891, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# The described method will help to see how data has been spread for numerical values. We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Checking missing values
df1.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
for i in df1.columns:
  val=df1[i].isnull().sum()
  if val!=0:
    print(i,val)
# Out:
# Age 177
# Cabin 687
# Embarked 2

# %%
sns.boxplot(df1['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#filling missing values of age column with median value
df1['Age']=df1['Age'].fillna(df1['Age'].median())

# %%
df1['Age'].isnull().sum()
# Out:
# 0

# %%
df1['Embarked']=df1['Embarked'].fillna(df1['Embarked'].mode()[0])

# %%
df1['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df1['Cabin']=df1['Cabin'].replace(np.nan,'C7')

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500    C7        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250    C7        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500    C7        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000    C7        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female  28.0      1      2        W./C. 6607  23.4500    C7        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500    C7        Q
#
# [891 rows x 11 columns]

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
#handling duplicate record
df1.duplicated().any()
# Out:
# False

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Handling Outlier -Outliers, being the most extreme observations, may include the sample maximum or sample minimum, or both, depending on whether they are extremely high or low. However, the sample maximum and minimum are not always outliers because they may not be unusually far from other observations.
#
# We Generally identify outliers with the help of boxplot, so here box plot shows some of the data points outside the range of the data.

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.boxplot(df1['Fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['Parch'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['SibSp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket  Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171  True    C7        S
# 1  female  38.0      1      0          PC 17599  True   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282  True    C7        S
# 3  female  35.0      1      0            113803  True  C123        S
# 4    male  35.0      0      0            373450  True    C7        S

# %%
df1.drop('Fare',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket Cabin Embarked
# 0      male  22.0      1      0         A/5 21171    C7        S
# 1    female  38.0      1      0          PC 17599   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282    C7        S
# 3    female  35.0      1      0            113803  C123        S
# 4      male  35.0      0      0            373450    C7        S
# ..      ...   ...    ...    ...               ...   ...      ...
# 886    male  27.0      0      0            211536    C7        S
# 887  female  19.0      0      0            112053   B42        S
# 888  female  28.0      1      2        W./C. 6607    C7        S
# 889    male  26.0      0      0            111369  C148        C
# 890    male  32.0      0      0            370376    C7        Q
#
# [891 rows x 10 columns]

# %%
df1['Fare']=df['Fare']

# %%
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500    C7        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250    C7        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500    C7        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000    C7        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female  28.0      1      2        W./C. 6607  23.4500    C7        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500    C7        Q
#
# [891 rows x 11 columns]

# %%
df3=df1.copy()

# %%
drop1=df1[df1['Fare'] > 500].index

# %%
drop1
# Out:
# Int64Index([258, 679, 737], dtype='int64')

# %%
df1.drop(drop1,inplace=True)

# %%
df1.shape
# Out:
# (888, 11)

# %%
sns.boxplot(df1['Fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4d5b31a1-66ce-44c7-a9d2-3ff9d141860a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d5b31a1-66ce-44c7-a9d2-3ff9d141860a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving road_accident.csv to road_accident.csv

# %% [markdown]
# Exploratory data analysis for road accidents dataset

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('road_accident.csv')

# %%
df.head()
# Out:
#    Index      Country Code  Year  Deaths  Sidedness
# 0      0  Afghanistan  AFG  1990    4154          0
# 1      1  Afghanistan  AFG  1991    4472          0
# 2      2  Afghanistan  AFG  1992    5106          0
# 3      3  Afghanistan  AFG  1993    5681          0
# 4      4  Afghanistan  AFG  1994    6001          0

# %%
df.shape
# Out:
# (8010, 6)

# %%
df1=df.copy()

# %%
df1.drop('Index',axis=1,inplace=True)

# %%
df1
# Out:
#           Country Code  Year  Deaths  Sidedness
# 0     Afghanistan  AFG  1990    4154          0
# 1     Afghanistan  AFG  1991    4472          0
# 2     Afghanistan  AFG  1992    5106          0
# 3     Afghanistan  AFG  1993    5681          0
# 4     Afghanistan  AFG  1994    6001          0
# ...           ...  ...   ...     ...        ...
# 8005     Zimbabwe  ZWE  2015    2373          1
# 8006     Zimbabwe  ZWE  2016    2436          1
# 8007     Zimbabwe  ZWE  2017    2473          1
# 8008     Zimbabwe  ZWE  2018    2509          1
# 8009     Zimbabwe  ZWE  2019    2554          1
#
# [8010 rows x 5 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8010 entries, 0 to 8009
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    8010 non-null   object
#  1   Code       6150 non-null   object
#  2   Year       8010 non-null   int64
#  3   Deaths     8010 non-null   int64
#  4   Sidedness  8010 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 313.0+ KB

# %%
df1.describe()
# Out:
#               Year        Deaths    Sidedness
# count  8010.000000  8.010000e+03  8010.000000
# mean   2004.500000  4.451661e+04     0.213483
# std       8.655982  1.269077e+05     0.409791
# min    1990.000000  0.000000e+00     0.000000
# 25%    1997.000000  3.322500e+02     0.000000
# 50%    2004.500000  1.969500e+03     0.000000
# 75%    2012.000000  1.323600e+04     0.000000
# max    2019.000000  1.285039e+06     1.000000

# %%
df1.columns
# Out:
# Index(['Country', 'Code', 'Year', 'Deaths', 'Sidedness'], dtype='object')

# %%
cat=df1.select_dtypes(include=['object'])

# %%
cat
# Out:
#           Country Code
# 0     Afghanistan  AFG
# 1     Afghanistan  AFG
# 2     Afghanistan  AFG
# 3     Afghanistan  AFG
# 4     Afghanistan  AFG
# ...           ...  ...
# 8005     Zimbabwe  ZWE
# 8006     Zimbabwe  ZWE
# 8007     Zimbabwe  ZWE
# 8008     Zimbabwe  ZWE
# 8009     Zimbabwe  ZWE
#
# [8010 rows x 2 columns]

# %%
#numerical columns
num=df1.select_dtypes(exclude=['object'])

# %%
num
# Out:
#       Year  Deaths  Sidedness
# 0     1990    4154          0
# 1     1991    4472          0
# 2     1992    5106          0
# 3     1993    5681          0
# 4     1994    6001          0
# ...    ...     ...        ...
# 8005  2015    2373          1
# 8006  2016    2436          1
# 8007  2017    2473          1
# 8008  2018    2509          1
# 8009  2019    2554          1
#
# [8010 rows x 3 columns]

# %%
df1.isnull().sum()
# Out:
# Country         0
# Code         1860
# Year            0
# Deaths          0
# Sidedness       0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#           Country Code  Year  Deaths  Sidedness
# 0     Afghanistan  AFG  1990    4154          0
# 1     Afghanistan  AFG  1991    4472          0
# 2     Afghanistan  AFG  1992    5106          0
# 3     Afghanistan  AFG  1993    5681          0
# 4     Afghanistan  AFG  1994    6001          0
# ...           ...  ...   ...     ...        ...
# 8005     Zimbabwe  ZWE  2015    2373          1
# 8006     Zimbabwe  ZWE  2016    2436          1
# 8007     Zimbabwe  ZWE  2017    2473          1
# 8008     Zimbabwe  ZWE  2018    2509          1
# 8009     Zimbabwe  ZWE  2019    2554          1
#
# [6150 rows x 5 columns]

# %%
df1.isnull().sum()
# Out:
# Country      0
# Code         0
# Year         0
# Deaths       0
# Sidedness    0
# dtype: int64

# %%
df1.Country.value_counts()
# Out:
# Afghanistan                 30
# Paraguay                    30
# North Korea                 30
# North Macedonia             30
# Northern Mariana Islands    30
#                             ..
# Grenada                     30
# Guam                        30
# Guatemala                   30
# Guinea                      30
# Zimbabwe                    30
# Name: Country, Length: 205, dtype: int64

# %%
df1.Year.value_counts()
# Out:
# 1990    205
# 1991    205
# 2018    205
# 2017    205
# 2016    205
# 2015    205
# 2014    205
# 2013    205
# 2012    205
# 2011    205
# 2010    205
# 2009    205
# 2008    205
# 2007    205
# 2006    205
# 2005    205
# 2004    205
# 2003    205
# 2002    205
# 2001    205
# 2000    205
# 1999    205
# 1998    205
# 1997    205
# 1996    205
# 1995    205
# 1994    205
# 1993    205
# 1992    205
# 2019    205
# Name: Year, dtype: int64

# %%
num
# Out:
#       Year  Deaths  Sidedness
# 0     1990    4154          0
# 1     1991    4472          0
# 2     1992    5106          0
# 3     1993    5681          0
# 4     1994    6001          0
# ...    ...     ...        ...
# 8005  2015    2373          1
# 8006  2016    2436          1
# 8007  2017    2473          1
# 8008  2018    2509          1
# 8009  2019    2554          1
#
# [8010 rows x 3 columns]

# %%
df1.Sidedness.value_counts()
# Out:
# 0    4560
# 1    1590
# Name: Sidedness, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
sns.countplot(df1.Sidedness)
plt.title('value counts')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(6,5))
sns.barplot(df1.Year,df1.Deaths)
plt.title('number of deaths in a year')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize= (6,5))
sns.barplot(data=df1,x='Sidedness',y='Deaths')
plt.xticks(rotation=90)
plt.title("Sidedness vs Deaths")
plt.show()

# %%
accidents_by_country=df1.groupby('Country').sum()

# %%
accidents_by_country
# Out:
#                  Year    Deaths  Sidedness
# Country
# Afghanistan     60135    208332          0
# Albania         60135      8522          0
# Algeria         60135    369395          0
# American Samoa  60135       164          0
# Andorra         60135       259          0
# ...               ...       ...        ...
# Vietnam         60135    594980          0
# World           60135  36317087          0
# Yemen           60135    278327          0
# Zambia          60135     56975         30
# Zimbabwe        60135     67207         30
#
# [205 rows x 3 columns]

# %%
accidents_by_country['Deaths'].sum()
# Out:
# 72613564

# %%
accidents_by_country.sort_values(by='Deaths',ascending=False)
# Out:
#                 Year    Deaths  Sidedness
# Country
# World          60135  36317087          0
# China          60135   8350399         30
# India          60135   5346154         30
# United States  60135   1359744          0
# Brazil         60135   1352192          0
# ...              ...       ...        ...
# San Marino     60135        90          0
# Tuvalu         60135        82         30
# Monaco         60135        70          0
# Niue           60135         0          0
# Tokelau        60135         0          0
#
# [205 rows x 3 columns]

# %%
plt.subplots(figsize=(15,6))
cr=accidents_by_country['Deaths'].sort_values(ascending=False)
ax=cr.plot.line()
ax.set_xlabel('Country') 
ax.set_ylabel('Total Number of Deaths') 
ax.set_title('Country Wise Stats') 
plt.show()
print(cr)
# Out:
# Country
# World            36317087
# China             8350399
# India             5346154
# United States     1359744
# Brazil            1352192
#                    ...
# San Marino             90
# Tuvalu                 82
# Monaco                 70
# Niue                    0
# Tokelau                 0
# Name: Deaths, Length: 205, dtype: int64

# %%
india_accidents=df1[df1['Country']=='India']

# %%
india_accidents
# Out:
#      Country Code  Year  Deaths  Sidedness
# 3420   India  IND  1990  129821          1
# 3421   India  IND  1991  135557          1
# 3422   India  IND  1992  138623          1
# 3423   India  IND  1993  141224          1
# 3424   India  IND  1994  144071          1
# 3425   India  IND  1995  145480          1
# 3426   India  IND  1996  147942          1
# 3427   India  IND  1997  157629          1
# 3428   India  IND  1998  163005          1
# 3429   India  IND  1999  167469          1
# 3430   India  IND  2000  169328          1
# 3431   India  IND  2001  170530          1
# 3432   India  IND  2002  169552          1
# 3433   India  IND  2003  166483          1
# 3434   India  IND  2004  168375          1
# 3435   India  IND  2005  175739          1
# 3436   India  IND  2006  183540          1
# 3437   India  IND  2007  190881          1
# 3438   India  IND  2008  199985          1
# 3439   India  IND  2009  202133          1
# 3440   India  IND  2010  207140          1
# 3441   India  IND  2011  213755          1
# 3442   India  IND  2012  218869          1
# 3443   India  IND  2013  213635          1
# 3444   India  IND  2014  204750          1
# 3445   India  IND  2015  201060          1
# 3446   India  IND  2016  199234          1
# 3447   India  IND  2017  199807          1
# 3448   India  IND  2018  208562          1
# 3449   India  IND  2019  211975          1

# %%
india_accidents_by_year=india_accidents.groupby('Year').sum()
plt.subplots(figsize=(15,6))
ax=india_accidents_by_year['Deaths']
cr=ax.plot()
cr.xaxis.set_ticks(np.arange(1990,2020,1))
cr.set(xlabel='Year', ylabel='Total Number of Deaths', title='Number of Deaths throught the years 1990 to 2019 of India')
plt.show()
